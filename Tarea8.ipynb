# %% [markdown]
# <a href="https://colab.research.google.com/github/joserlandero/Aprendizaje-Automatico/blob/main/Tarea8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Recargamos la base de datos del cafe
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler, StandardScaler, PolynomialFeatures
from sklearn.cluster import DBSCAN
#df = pd.read_csv('/content/kc_house_data.csv')
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
url = 'https://raw.githubusercontent.com/joserlandero/Aprendizaje-Automatico/refs/heads/main/kc_house_data.csv'
df = pd.read_csv(url)
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# ## Random Forest

# %%
# Separamos los datos
X =["floors", "waterfront", "lat", "bedrooms", "sqft_basement", "view",
           "bathrooms", "sqft_living15", "sqft_above", "grade", "sqft_living"]
X = df[X]
y = df['price']

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)


scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
# Crear y entrenar modelo
model = RandomForestRegressor(n_estimators = 2500,max_depth=15)
model.fit(x_train, y_train)

# Predicciones
y_pred = model.predict(x_test)

rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("RMSE:", rmse)
print("MAE:", mae)
print("R2:", r2)

print('Vemos una mejora signficativa en los resultados')
# Out:
# RMSE: 174545.88933603725
# MAE: 91747.90784794485
# R2: 0.788965855539482
# Vemos una mejora signficativa en los resultados

# %%
# Separamos los datos
X =["floors", "waterfront", "lat", "bedrooms", "sqft_basement", "view",
           "bathrooms", "sqft_living15", "sqft_above", "grade", "sqft_living"]
X = df[X]
y = df['price']

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)


scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
# Crear y entrenar modelo
model = RandomForestRegressor(n_estimators = 2000,max_depth=15,n_jobs=-1)
model.fit(x_train, y_train)

# Predicciones
y_pred = model.predict(x_test)

rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("RMSE:", rmse)
print("MAE:", mae)
print("R2:", r2)

print('Vemos una mejora signficativa en los resultados')
# Out:
# RMSE: 174312.34944751082
# MAE: 91748.0245889372
# R2: 0.7895301990427601
# Vemos una mejora signficativa en los resultados

# %%
# Separamos los datos
X =["floors", "waterfront", "lat", "bedrooms", "sqft_basement", "view",
           "bathrooms", "sqft_living15", "sqft_above", "grade", "sqft_living"]
X = df[X]
y = df['price']

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)


scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
# Crear y entrenar modelo
model = RandomForestRegressor(n_estimators = 2000,max_depth=15,n_jobs=-1,min_samples_split=5)
model.fit(x_train, y_train)

# Predicciones
y_pred = model.predict(x_test)

rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("RMSE:", rmse)
print("MAE:", mae)
print("R2:", r2)

print('Vemos una mejora signficativa en los resultados')
# Out:
# RMSE: 172989.78819648977
# MAE: 91744.16450833381
# R2: 0.7927118807287199
# Vemos una mejora signficativa en los resultados

# %%
# Separamos los datos
X =["floors", "waterfront", "lat", "bedrooms", "sqft_basement", "view",
           "bathrooms", "sqft_living15", "sqft_above", "grade", "sqft_living"]
X = df[X]
y = df['price']

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)


scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
# Crear y entrenar modelo
model = RandomForestRegressor(n_estimators = 2000,max_depth=15,n_jobs=-1,min_samples_split=8)
model.fit(x_train, y_train)

# Predicciones
y_pred = model.predict(x_test)

rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("RMSE:", rmse)
print("MAE:", mae)
print("R2:", r2)

print('Vemos una mejora signficativa en los resultados')
# Out:
# RMSE: 171600.12644565053
# MAE: 91830.26831615117
# R2: 0.796028878226748
# Vemos una mejora signficativa en los resultados

# %% [markdown]
# # Experimento usando GridSearch

# %%
# --- Tu código (con una pequeña corrección en test_size) ---
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
# Asumimos que 'df' ya está cargado
# df = pd.read_csv('tu_archivo.csv')

# Separamos los datos
X_cols = ["floors", "waterfront", "lat", "bedrooms", "sqft_basement", "view",
          "bathrooms", "sqft_living15", "sqft_above", "grade", "sqft_living"]
X = df[X_cols]
y = df['price']

# Corregí el '0.2 0' a '0.20'
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# --- Aquí empieza el GridSearchCV con Random Forest ---

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import r2_score

rf = RandomForestRegressor()
param_grid = {
    'n_estimators': [1500, 2000,2500],
    'max_depth': [10,15,12],
    'min_samples_split':[3,5,8]
}


grid_search = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    cv=2,                          # 3 folds de validación cruzada
    scoring='r2', # Métrica para regresión
    verbose=3                       # Muestra mensajes mientras se ejecuta
)

grid_search.fit(x_train, y_train)

print("Mejores parámetros encontrados:")
print(grid_search.best_params_)
print(f"{grid_search.best_score_}")


# 'rid_search.best_estimator_ es el modelo ya entrenado con los mejores parámetros
best_rf_model = grid_search.best_estimator_
y_pred = best_rf_model.predict(x_test)

r2 = r2_score(y_test, y_pred)
print(f"R-cuadrado en el set de Test: {r2:.4f}")
# Out:
# Fitting 2 folds for each of 27 candidates, totalling 54 fits
# [CV 1/2] END max_depth=10, min_samples_split=3, n_estimators=1500;, score=0.782 total time=  50.3s
# [CV 2/2] END max_depth=10, min_samples_split=3, n_estimators=1500;, score=0.802 total time=  48.1s
# [CV 1/2] END max_depth=10, min_samples_split=3, n_estimators=2000;, score=0.782 total time= 1.1min
# [CV 2/2] END max_depth=10, min_samples_split=3, n_estimators=2000;, score=0.801 total time= 1.1min
# [CV 1/2] END max_depth=10, min_samples_split=3, n_estimators=2500;, score=0.782 total time= 1.3min
# [CV 2/2] END max_depth=10, min_samples_split=3, n_estimators=2500;, score=0.801 total time= 1.4min
# [CV 1/2] END max_depth=10, min_samples_split=5, n_estimators=1500;, score=0.781 total time=  48.0s
# [CV 2/2] END max_depth=10, min_samples_split=5, n_estimators=1500;, score=0.800 total time=  47.2s
# [CV 1/2] END max_depth=10, min_samples_split=5, n_estimators=2000;, score=0.782 total time= 1.1min
# ...
